# %%
import threading,time

# %%
print('Currently running thread:',threading.current_thread().name)
# Out:
# Currently running thread: MainThread

# %%
if threading.current_thread() == threading.main_thread():
    print("Main Thread")
else:
    print("Not Main Thread")
# Out:
# Main Thread

# %%
def display(i:int):
    print(f"This is a thread {i}")
for i in range(5):
    t = threading.Thread(target=display,args=(i,))
    t.start()
# Out:
# This is a thread 0
# This is a thread 1
# This is a thread 2
# This is a thread 3
# This is a thread 4
